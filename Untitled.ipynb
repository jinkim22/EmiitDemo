# %%
import pandas as pd
from datetime import datetime
from sklearn.model_selection import train_test_split
import numpy as np
dateparse = lambda x: datetime.strptime(x, '%Y-%m')

# %%
df = pd.read_csv("emission.csv")
df = df.dropna()

# %%
# df = pd.read_csv("emission.csv",  parse_dates=['Date'], date_parser=dateparse)

# %%
df = df.set_index('Date')

# %%
from statsmodels.tsa.stattools import adfuller

df.columns = df.columns.str.replace(' ','_')

# %%
X_train, X_test, y_train, y_test = train_test_split(df, df['three_month_prediction'], test_size = 0.25)

# %%
X_train.head()
# Out:
#          Emission_value__Natural_gas  Emission_value__Landfill_gas  \
# Date
# 2021-01                   1233954.69                     192304.63
# 2020-02                    111400.76                      17361.16
# 2019-01                   1112672.40                     173403.49
# 2020-05                   1757322.22                     273868.40
# 2019-09                    431499.78                      67246.72
#
#          Emission_value__Liquefied_petroleum_gas  Emission_value__#2_fuel_oil  \
# Date
# 2021-01                                104165.01                     38460.93
# 2020-02                                  9403.96                      3472.23
# 2019-01                                 93926.89                     34680.70
# 2020-05                                148345.38                     54773.68
# 2019-09                                 36425.31                     13449.34
#
#          Emission_value___#6_fuel_oil  Emission_value__Kerosene  \
# Date
# 2021-01                      19230.46                  14422.85
# 2020-02                       1736.12                   1302.09
# 2019-01                      17340.35                  13005.26
# 2020-05                      27386.84                  20540.13
# 2019-09                       6724.67                   5043.50
#
#          Emission_value__Wood\n  Emission_value__Anthracite_coal\n  \
# Date
# 2021-01                10994.41                         3925005.48
# 2020-02                  992.57                          354347.37
# 2019-01                 9913.80                         3539226.60
# 2020-05                15657.57                         5589750.90
# 2019-09                 3844.62                         1372529.34
#
#          Emission_value__Bituminous_coal\n  \
# Date
# 2021-01                         4870525.01
# 2020-02                          439708.36
# 2019-01                         4391813.40
# 2020-05                         6936301.54
# 2019-09                         1703166.66
#
#          Emission_value__Sub-bituminous_coal\n  ...  \
# Date                                            ...
# 2021-01                             1198391.03  ...
# 2020-02                              108190.09  ...
# 2019-01                             1080604.20  ...
# 2020-05                             1706674.65  ...
# 2019-09                              419063.58  ...
#
#          Emission_Value_Recreational_equipment  Emission_Value_Mobile_Sources  \
# Date
# 2021-01                              361105.36                     2388804.52
# 2020-02                               32600.40                      215659.98
# 2019-01                              325613.22                     2154014.95
# 2020-05                              514263.99                     3401988.17
# 2019-09                              126274.40                      835337.51
#
#          Emission_Value_R-22  Emission_Value_R-407C  Emission_Value_R-410A  \
# Date
# 2021-01             56516.19               22364.32               21367.18
# 2020-02              5102.25                2019.04                1929.02
# 2019-01             50961.36               20166.18               19267.05
# 2020-05             80486.88               31849.88               30429.82
# 2019-09             19763.06                7820.54                7471.86
#
#          Emission_Value_R-22.1  Emission_Value_R-134A  \
# Date
# 2021-01               42912.42               34899.73
# 2020-02                3874.11                3150.73
# 2019-01               38694.67               31469.52
# 2020-05               61113.23               49702.04
# 2019-09               15005.98               12204.03
#
#          Emission_Value_Refrigeration  Emission_Scope1  three_month_prediction
# Date
# 2021-01                     178059.84      17796473.29             29478192.36
# 2020-02                      16075.15       1606655.96             25344640.42
# 2019-01                     160558.79      16047302.83             16321281.18
# 2020-05                     253581.85      25344640.42              4437367.95
# 2019-09                      62265.48       6223222.32              1656916.63
#
# [5 rows x 96 columns]

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000)
# Train the model on training data
rf.fit(X_train, y_train);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)
# Calculate the absolute errors
errors = (abs(predictions - y_test) / y_test)
# Print out the mean absolute error (mae)

# %%
sum(errors) / len(errors)
# Out:
# 0.3202697739104363

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, importance) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Emission_value__Diesel
#  Importance: 0.07088949944208064
# Variable: Emission_value__Gasoline
#  Importance: 0.03717881759027388
# Variable: Emission_value__Gasoline Importance: 0.005501432656171251
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.2 Importance: 0.004673729262620631
# Variable: Emission_value__#2_fuel_oil Importance: 0.004478504233371155
# Variable: Emission_Value_liquid_or_gas_Fuel Importance: 0.004265391473822698
# Variable: Emission_Value_R-134A Importance: 0.0038969876784046608
# Variable: Emission_value__CNG_/_LNG
#  Importance: 0.0038777101632142775
# Variable: Emission_value__LPG.6 Importance: 0.0037034868851780686
# Variable: Emission_Value_R-22  Importance: 0.003678358506219428
# Variable: Emission_value__Sub-bituminous_coal
#  Importance: 0.003616496395466091
# Variable: Emission_Value_R-22.1 Importance: 0.0035534933388253302
# Variable: Emission_Value_Stationary_Combustion Importance: 0.0034000144458627007
# Variable: Emission_value__Diesel
# .1 Importance: 0.0033972807952057666
# Variable: Emission_value__LPG.4 Importance: 0.002973214198856005
# Variable: Emission_value__Biodiesel Importance: 0.0029506543142900628
# Variable: Emission_value__Biodiesel.1 Importance: 0.002928174095941271
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.2 Importance: 0.002893831617431669
# Variable: Emission_value__Gasoline_for_2-stroke_equipment Importance: 0.0028235648276533874
# Variable: Emission_value__Iron Importance: 0.002769001541569896
# Variable: Emission_value__Lime_stone Importance: 0.0026985383286006895
# Variable: Emission_value__Diesel Importance: 0.002639189454656177
# Variable: Emission_Value_Logging_equipment Importance: 0.0026283996420977387
# Variable: Emission_Value_Car   Importance: 0.002615478326874168
# Variable: Emission_value__Gasoline.1 Importance: 0.0024901535084342463
# Variable: Emission_Value_Industrial_or_commercial_equipment Importance: 0.0024293599296631835
# Variable: Emission_value__Natural_gas Importance: 0.0024072690303774324
# Variable: Emission_value__Diesel.5 Importance: 0.0023802695842939183
# Variable: Emission_value__Diesel.7 Importance: 0.0023785069823573602
# Variable: Emission_value__Bituminous_coal
#  Importance: 0.0023730606236708578
# Variable: Emission_value__Ethanol_/_Methanol_/_LPG
# .1 Importance: 0.0022605779851466033
# Variable: Emission_value__Liquefied_petroleum_gas Importance: 0.0022200364990799634
# Variable: Emission_value__Gasoline_for_4-stroke_equipment Importance: 0.002206249518696847
# Variable: Emission_value__Biodiesel.2 Importance: 0.0021747106778730553
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.5 Importance: 0.00207344207809548
# Variable: Emission_Value_Solid_fuel Importance: 0.002053898977426748
# Variable: Emission_value__Landfill_gas Importance: 0.0020403463815676925
# Variable: Emission_value__Diesel.1 Importance: 0.0019264105021180448
# Variable: Emission_Value_Bus   Importance: 0.0018199167970193695
# Variable: Emission_value__Diesel.4 Importance: 0.0017978377337226508
# Variable: Emission_value__Gasoline
# .1 Importance: 0.0017931869850119837
# Variable: Emission_value__CNG_/_LNG
# .1 Importance: 0.0017493433106376434
# Variable: Emission_Value_Refrigeration Importance: 0.0017140295168488783
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.5 Importance: 0.0016227432503648034
# Variable: Emission_value__Wood
#  Importance: 0.0015419418406768428
# Variable: Emission_value__Lignite_coal Importance: 0.0014860750125600761
# Variable: Emission_value__Kerosene Importance: 0.0014749143209285543
# Variable: Emission_value__LPG  Importance: 0.0014169251958839808
# Variable: Emission_Value_Ship_or_boat Importance: 0.0013570271580551
# Variable: Emission_value__LPG.1 Importance: 0.001307593190393732
# Variable: Emission_value__CNG_/_LNG Importance: 0.0012763478688643903
# Variable: Emission_value___#6_fuel_oil Importance: 0.001197028188832141
# Variable: Emission_Value_Construction_or_mining_equipment Importance: 0.0011930793097815456
# Variable: Emission_Value_R-407C Importance: 0.0011605969290658176
# Variable: Emission_Value_Mobile_Sources Importance: 0.0010996196378704008
# Variable: Emission_Value_R-410A Importance: 0.0009463326955254708
# Variable: Emission_Value_Recreational_equipment Importance: 0.0007379586539944972
# Variable: Emission_value__Anthracite_coal
#  Importance: 0.0007327296334336142
# Variable: Emission_value__Ethanol_/_Methanol_/_LPG
#  Importance: 0.0006663593230919517
# Variable: Emission_value__Ethanol_/_Methanol_CNG_/_LNG Importance: 0.0005934340080006069
# Variable: Emission_Scope1      Importance: 0.0005695844678851843
# Variable: Emission_Value_Medium-duty_trucks Importance: 0.0005598826490659939
# Variable: Emission_value__Diesel.8 Importance: 0.0005279090881429986
# Variable: Emission_value__Biodiesel.3 Importance: 0.0005135037612988501
# Variable: Emission_Value_Light-duty_trucks Importance: 0.00048798646461588774
# Variable: Emission_value__Ethanol_/_Methanol_CNG_/_LNG.1 Importance: 0.0
# Variable: Emission_value__LPG.2 Importance: 0.0
# Variable: Emission_value__Biodiesel.4 Importance: 0.0
# Variable: Emission_value__Residual_fuel_oil Importance: 0.0
# Variable: Emission_value__Diesel.2 Importance: 0.0
# Variable: Emission_value__Jet_fuel_for_aircraft Importance: 0.0
# Variable: Emission_value__Aviation_gasoline_for_aircraft Importance: 0.0
# Variable: Emission_value__Gasoline_for_airport_equipment Importance: 0.0
# Variable: Emission_value__Diesel_for_airport_equipment Importance: 0.0
# Variable: Emission_value__LPG_for_airport_equipment Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.1 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.1 Importance: 0.0
# Variable: Emission_value__Diesel.3 Importance: 0.0
# Variable: Emission_value__LPG.3 Importance: 0.0
# Variable: Emission_value__Gasoline_for_off-road_trucks Importance: 0.0
# Variable: Emission_value__Diesel_for_off-road_trucks Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.3 Importance: 0.0
# Variable: Emission_value__Diesel.6 Importance: 0.0
# Variable: Emission_value__LPG.5 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.3 Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.4 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.4 Importance: 0.0
# Variable: Emission_value___
# Gasoline_for_2-stroke_equipment
#  Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.6 Importance: 0.0
# Variable: Emission_value__Diesel.9 Importance: 0.0
# Variable: Emission_value__LPG.7 Importance: 0.0
# Variable: Emission_Value_Motorcycle Importance: 0.0
# Variable: Emission_Value_Aircrafts Importance: 0.0
# Variable: Emission_Value_Agriculture_equipment Importance: 0.0
# Variable: Emission_Value_Lawn_and_garden_equipment Importance: 0.0

# %%
# creating a model to predict emission values three months forward. Created a random forest regression model
# to show feature importance for each x variable. Our heuristics agree with the fact that Logging Equipment 
# and limestone ranked in the top 20
# 
# Further steps can include loooking into advancing our feature selection process by comparing which features
# are important for different types of industries.
#
#

# %%
# for jason:
# It seems that some of these variables are overlapping in terms of what they represent. Some thought needs to be
# put into how we should use these values. Maybe they should be taken out? i.e. Emission_value_diesel is the sum of
# 10 other features. Not really necessary.
# 
# also, I just pulled code from https://towardsdatascience.com/random-forest-in-python-24d0893d51c0 for this notebook.
# Might need to think more about the uniqueness of our problem and do thorough testing to produce better accuracy and
# also a well working model for the real world. I'm a bit worried that i skipped a bunch of steps an
