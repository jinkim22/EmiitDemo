# %%
import pandas as pd
from datetime import datetime
from sklearn.model_selection import train_test_split
import numpy as np
dateparse = lambda x: datetime.strptime(x, '%Y-%m')

# %%
df = pd.read_csv("emission.csv")
df = df.dropna()

# %%
# df = pd.read_csv("emission.csv",  parse_dates=['Date'], date_parser=dateparse)

# %%
df = df.set_index('Date')

# %%
from statsmodels.tsa.stattools import adfuller

df.columns = df.columns.str.replace(' ','_')

# %%
X_train, X_test, y_train, y_test = train_test_split(df, df['three_month_prediction'], test_size = 0.25)

# %%
X_train.head()
# Out:
#          Emission_value__Natural_gas  Emission_value__Landfill_gas  \
# Date
# 2019-08                    307567.98                      47932.67
# 2019-01                   1112672.40                     173403.49
# 2019-06                   1049349.58                     163535.00
# 2021-09                    819868.45                     127771.71
# 2021-07                    905221.44                     141073.47
#
#          Emission_value__Liquefied_petroleum_gas  Emission_value__#2_fuel_oil  \
# Date
# 2019-08                                 25963.53                      9586.53
# 2019-01                                 93926.89                     34680.70
# 2019-06                                 88581.46                     32707.00
# 2021-09                                 69209.67                     25554.34
# 2021-07                                 76414.80                     28214.69
#
#          Emission_value___#6_fuel_oil  Emission_value__Kerosene  \
# Date
# 2019-08                       4793.27                   3594.95
# 2019-01                      17340.35                  13005.26
# 2019-06                      16353.50                  12265.12
# 2021-09                      12777.17                   9582.88
# 2021-07                      14107.35                  10580.51
#
#          Emission_value__Wood\n  Emission_value__Anthracite_coal\n  \
# Date
# 2019-08                 2740.40                          978322.80
# 2019-01                 9913.80                         3539226.60
# 2019-06                 9349.60                         3337807.20
# 2021-09                 7304.95                         2607865.73
# 2021-07                 8065.43                         2879359.44
#
#          Emission_value__Bituminous_coal\n  \
# Date
# 2019-08                         1213997.20
# 2019-01                         4391813.40
# 2019-06                         4141872.80
# 2021-09                         3236091.08
# 2021-07                         3572986.65
#
#          Emission_value__Sub-bituminous_coal\n  ...  \
# Date                                            ...
# 2019-08                              298703.60  ...
# 2019-01                             1080604.20  ...
# 2019-06                             1019106.40  ...
# 2021-09                              796239.12  ...
# 2021-07                              879132.16  ...
#
#          Emission_Value_Recreational_equipment  Emission_Value_Mobile_Sources  \
# Date
# 2019-08                               90006.91                      595418.77
# 2019-01                              325613.22                     2154014.95
# 2019-06                              307082.39                     2031428.74
# 2021-09                              239926.87                     1587177.77
# 2021-07                              264904.63                     1752412.04
#
#          Emission_Value_R-22  Emission_Value_R-407C  Emission_Value_R-410A  \
# Date
# 2019-08             14086.88                5574.39                5325.85
# 2019-01             50961.36               20166.18               19267.05
# 2019-06             48061.12               19018.51               18170.56
# 2021-09             37550.68               14859.38               14196.86
# 2021-07             41459.93               16406.32               15674.83
#
#          Emission_Value_R-22.1  Emission_Value_R-134A  \
# Date
# 2019-08               10696.09                8698.89
# 2019-01               38694.67               31469.52
# 2019-06               36492.53               29678.57
# 2021-09               28512.02               23188.20
# 2021-07               31480.28               25602.22
#
#          Emission_Value_Refrigeration  Emission_Scope1  three_month_prediction
# Date
# 2019-08                      44382.10       4435839.81             12524724.16
# 2019-01                     160558.79      16047302.83             16321281.18
# 2019-06                     151421.30      15134041.70              6223222.32
# 2021-09                     118307.14      11824394.36              2156038.14
# 2021-07                     130623.58      13055381.35              6329758.43
#
# [5 rows x 96 columns]

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000)
# Train the model on training data
rf.fit(X_train, y_train);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(X_test)
# Calculate the absolute errors
errors = (abs(predictions - y_test) / y_test)
# Print out the mean absolute error (mae)

# %%
sum(errors) / len(errors)
# Out:
# 0.1283358162017315

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, importance) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Emission_value__Diesel.4 Importance: 0.02182177076337118
# Variable: Emission_value__Biodiesel.2 Importance: 0.021154738278564567
# Variable: Emission_Value_R-407C Importance: 0.020371155390366213
# Variable: Emission_value__Gasoline_for_2-stroke_equipment Importance: 0.020096056463160355
# Variable: Emission_Value_Logging_equipment Importance: 0.019831063754988332
# Variable: Emission_value__LPG.6 Importance: 0.01969440774928249
# Variable: Emission_Scope1      Importance: 0.018936949152054704
# Variable: Emission_value__CNG_/_LNG
#  Importance: 0.018931642592549265
# Variable: Emission_value__Lime_stone Importance: 0.01866360646149705
# Variable: Emission_Value_Bus   Importance: 0.018612976511070904
# Variable: Emission_value__Diesel
# .1 Importance: 0.018467447785232943
# Variable: Emission_value__Ethanol_/_Methanol_/_LPG
# .1 Importance: 0.01827969274039021
# Variable: Emission_value__Diesel Importance: 0.01811656903687728
# Variable: Emission_value__Gasoline.1 Importance: 0.017996348065690386
# Variable: Emission_Value_Solid_fuel Importance: 0.017807496737736767
# Variable: Emission_value__LPG.1 Importance: 0.01769371714991304
# Variable: Emission_value__Iron Importance: 0.01749313006536843
# Variable: Emission_value___#6_fuel_oil Importance: 0.017090491243641433
# Variable: Emission_Value_Light-duty_trucks Importance: 0.017043261174808158
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.5 Importance: 0.01702545797247896
# Variable: Emission_value__Ethanol_/_Methanol_CNG_/_LNG Importance: 0.016999765981345647
# Variable: Emission_Value_R-22.1 Importance: 0.01697119551063416
# Variable: Emission_Value_Recreational_equipment Importance: 0.016933369428522773
# Variable: Emission_value__#2_fuel_oil Importance: 0.016830606574780794
# Variable: Emission_value__Kerosene Importance: 0.01680407185809768
# Variable: Emission_value__Liquefied_petroleum_gas Importance: 0.016753978697756522
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.2 Importance: 0.01664925668208961
# Variable: Emission_value__Biodiesel.3 Importance: 0.016582945697026636
# Variable: Emission_value__Biodiesel.1 Importance: 0.016262124566580338
# Variable: Emission_value__Diesel.1 Importance: 0.01617179550711915
# Variable: Emission_value__Natural_gas Importance: 0.016088700802457823
# Variable: Emission_value__Ethanol_/_Methanol_/_LPG
#  Importance: 0.015826076684447687
# Variable: Emission_Value_liquid_or_gas_Fuel Importance: 0.015612001364728956
# Variable: Emission_value__Biodiesel Importance: 0.015523388550829277
# Variable: Emission_value__Gasoline
# .1 Importance: 0.015300061235371656
# Variable: Emission_value__CNG_/_LNG
# .1 Importance: 0.015275356516482808
# Variable: Emission_value__Gasoline_for_4-stroke_equipment Importance: 0.015235409828732494
# Variable: Emission_value__Diesel.7 Importance: 0.015206769587952246
# Variable: Emission_value__CNG_/_LNG Importance: 0.01519371037621585
# Variable: Emission_value__Sub-bituminous_coal
#  Importance: 0.015170015864279476
# Variable: Emission_value__Gasoline Importance: 0.015112711474060757
# Variable: Emission_value__Wood
#  Importance: 0.014925750017065587
# Variable: Emission_value__LPG  Importance: 0.014751104776253708
# Variable: Emission_Value_Ship_or_boat Importance: 0.014679525506521608
# Variable: Emission_value__Diesel.8 Importance: 0.014606123784417438
# Variable: Emission_value__Lignite_coal Importance: 0.014508466397003325
# Variable: Emission_Value_Medium-duty_trucks Importance: 0.014104451359512328
# Variable: Emission_value__LPG.4 Importance: 0.01404616524258
# Variable: Emission_Value_Stationary_Combustion Importance: 0.014015199425322306
# Variable: Emission_Value_Industrial_or_commercial_equipment Importance: 0.013483117067915799
# Variable: Emission_Value_R-22  Importance: 0.013480528861658077
# Variable: Emission_value__Bituminous_coal
#  Importance: 0.013108680295998513
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.2 Importance: 0.012724508937400692
# Variable: Emission_value__Anthracite_coal
#  Importance: 0.01271491736015902
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.5 Importance: 0.012614203467958293
# Variable: Emission_Value_R-134A Importance: 0.012502587911605818
# Variable: Emission_Value_Construction_or_mining_equipment Importance: 0.012433226518863886
# Variable: Emission_Value_Car   Importance: 0.012283557876182138
# Variable: Emission_Value_Mobile_Sources Importance: 0.011613674314803287
# Variable: Emission_Value_R-410A Importance: 0.011472438103625412
# Variable: Emission_Value_Refrigeration Importance: 0.01089437426707801
# Variable: Emission_value__Diesel.5 Importance: 0.0101429662520708
# Variable: Emission_value__Landfill_gas Importance: 0.0071052106246493945
# Variable: Emission_value__Diesel
#  Importance: 0.003952571159780118
# Variable: Emission_value__Gasoline
#  Importance: 0.0022053585930195685
# Variable: Emission_value__Ethanol_/_Methanol_CNG_/_LNG.1 Importance: 0.0
# Variable: Emission_value__LPG.2 Importance: 0.0
# Variable: Emission_value__Biodiesel.4 Importance: 0.0
# Variable: Emission_value__Residual_fuel_oil Importance: 0.0
# Variable: Emission_value__Diesel.2 Importance: 0.0
# Variable: Emission_value__Jet_fuel_for_aircraft Importance: 0.0
# Variable: Emission_value__Aviation_gasoline_for_aircraft Importance: 0.0
# Variable: Emission_value__Gasoline_for_airport_equipment Importance: 0.0
# Variable: Emission_value__Diesel_for_airport_equipment Importance: 0.0
# Variable: Emission_value__LPG_for_airport_equipment Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.1 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.1 Importance: 0.0
# Variable: Emission_value__Diesel.3 Importance: 0.0
# Variable: Emission_value__LPG.3 Importance: 0.0
# Variable: Emission_value__Gasoline_for_off-road_trucks Importance: 0.0
# Variable: Emission_value__Diesel_for_off-road_trucks Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.3 Importance: 0.0
# Variable: Emission_value__Diesel.6 Importance: 0.0
# Variable: Emission_value__LPG.5 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.3 Importance: 0.0
# Variable: Emission_value__Gasoline_for_2-stroke_equipment.4 Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.4 Importance: 0.0
# Variable: Emission_value___
# Gasoline_for_2-stroke_equipment
#  Importance: 0.0
# Variable: Emission_value__Gasoline_for_4-stroke_equipment.6 Importance: 0.0
# Variable: Emission_value__Diesel.9 Importance: 0.0
# Variable: Emission_value__LPG.7 Importance: 0.0
# Variable: Emission_Value_Motorcycle Importance: 0.0
# Variable: Emission_Value_Aircrafts Importance: 0.0
# Variable: Emission_Value_Agriculture_equipment Importance: 0.0
# Variable: Emission_Value_Lawn_and_garden_equipment Importance: 0.0
